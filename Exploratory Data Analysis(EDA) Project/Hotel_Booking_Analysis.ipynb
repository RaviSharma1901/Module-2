# %% [markdown]
# # **Project Name**  - Detailed EDA on Hotel Bookings: Discovering Patterns and Strategic Insights.

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name** - Ravi Sharma

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Analyzing hotel bookings data is crucial for the hospitality industry, as it reveals customer booking behaviors and preferred booking channels. This project focuses on evaluating data from both City and Resort Hotels.
#
# The project activities are structured as follows:
#
# **Problem Definition:** Establishing the study's business objectives.
#
# **Data Collection and Preparation:** Cleaning the data and addressing outliers.
#
# **Exploratory Data Analysis (EDA):** Investigating the relationships between various features, creating new variables as needed, and presenting the data in a clear and comprehensible manner.
#
# **Observations and Recommendations:** Drawing insights and providing actionable recommendations based on the EDA.

# %% [markdown]
# ### **GitHub Link -**

# %% [markdown]
# **https://github.com/RaviSharma1901/Module-2/Exploratory Data Analysis(EDA) Project/Hotel_Booking_Analysis.ipynb**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This project undertakes a thorough analysis of customer booking behavior to address a range of business challenges faced by hotels. By rigorously examining various dimensions of booking patterns, we aim to provide insights that can inform strategic decision-making and operational improvements.
#
# 1) Identifying the origin of guests is essential for understanding where most guests come from. This insight allows hotels to target those countries with increased public advertisements to boost footfall. Additionally, hotels can focus on retaining these guests through personalized follow-up contacts via emails, phone calls, and other methods even after their departure.
#
# 2) Analyzing the monthly booking patterns and identifying the busiest quarter or trimester of the year is crucial for optimizing hotel operations and maximizing revenue. This analysis helps in making informed decisions about staffing, promotions, and pricing strategies.
#
# 3) Analyzing the duration of guests' stays is crucial for developing smart pricing strategies aimed at encouraging longer stays.
#
# 4) Analyzing meal patterns is essential for optimizing kitchen inventory and manpower requirements in a hotel cafeteria. This helps in ensuring efficient operations, minimizing waste, and providing a better dining experience for guests.
#
# 5) Analyzing booking patterns across different market segments is crucial for recognizing and rewarding those segments that contribute the most business. This study will help hotels tailor their marketing strategies, enhance customer satisfaction, and drive increased bookings.
#
# 6) Understanding how the Average Daily Rate (ADR) depends on factors such as season, room type, and the allotment of demanded room types is crucial for optimizing pricing strategies and maximizing occupancy.
#
# 7) Analyzing booking cancellation patterns is essential for understanding the factors that contribute to cancellations. This analysis can help hotels plan for overbooking and devise strategies such as penalty amounts to mitigate the impact of cancellations.
#
# 8) Understanding customer retention patterns based on hotel type (City Hotels vs. Resort Hotels) is crucial for identifying areas where improvements can enhance the guest experience and foster loyalty.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Maximise Bookings, Minimise Cancellations , Maximise Customer retention as well as stay longevity.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# function to get the data from drive
def load_data(path_link):
  try:
      return pd.read_csv(path_link)
  except FileNotFoundError:
      print("Error: The file was not found. Please check the file path and try again.")
  except Exception as e:
      print("An error occurred:", str(e))
path = '/content/drive/MyDrive/Colab Notebooks/Module2(Numerical Programming in Python)/EDA/Hotel Bookings.csv'
hotel_df = load_data(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# Dataset First 5 row of Data
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Dataset last 5 row of Data
hotel_df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('Number of rows {} and Number of Column {}'.format(hotel_df.shape[0],hotel_df.shape[1]))
# Out:
# Number of rows 119390 and Number of Column 32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
def duplicate_val_cnt(df):
  try:
      return print('Count of Duplicate Value is {}'.format(df.duplicated().sum()))
  except FileNotFoundError:
      print("Error: The file was not found. Please check the file path and try again.")
  except Exception as e:
      print("An error occurred:", {e})
duplicate_val_cnt(hotel_df)
# Out:
# Count of Duplicate Value is 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# function to find Missing Values/Null Values Count
def missing_val_cnt(df):
  try:
      null_val = df.isnull().sum()
      # reset the index and rename the column
      after_reset_col = null_val.reset_index().rename(columns={'index':'Column',0:'Null Values'})
      return after_reset_col
  except Exception as e:
      print("An error occurred:", {e})

# get Missing Values/Null Values count
missing_val_cnt(hotel_df)
# Out:
#                             Column  Null Values
# 0                            hotel            0
# 1                      is_canceled            0
# 2                        lead_time            0
# 3                arrival_date_year            0
# 4               arrival_date_month            0
# 5         arrival_date_week_number            0
# 6        arrival_date_day_of_month            0
# 7          stays_in_weekend_nights            0
# 8             stays_in_week_nights            0
# 9                           adults            0
# 10                        children            4
# 11                          babies            0
# 12                            meal            0
# 13                         country          488
# 14                  market_segment            0
# 15            distribution_channel            0
# 16               is_repeated_guest            0
# 17          previous_cancellations            0
# 18  previous_bookings_not_canceled            0
# ...

# %%
# Visualizing the missing values
def missing_val_visual(df):
  try:
      plt.figure(figsize=(10,5))
      sns.heatmap(df.isnull(),cbar=False)
      plt.title('Missing Values Heatmap')
      plt.xlabel("Column Labels")
      plt.ylabel("Row Index")
      plt.show()
  except Exception as e:
      print("An error occurred:", {e})
missing_val_visual(hotel_df)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# We are working with a comprehensive dataset from the hotel industry that encompasses 119,390 entries across 32 different attributes. While most columns are complete, four of them (children, country, agent, and company) contain some missing values.
#
# Additionally, the dataset includes 31,994 instances of duplicate records. Our objective is to delve into this data, exploring various factors influencing hotel bookings and drawing actionable insights.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * **Hotel:**  H1= Resort Hotel, H2= City Hotel
# * **is_canceled** : If the booking was canceled(1) or not(0)
# * **lead_time** : Number of days that elapsed between the entering date of the  booking into the PMS(Property Management System) and the arrival date
# * **arrival_date_year** : Year of arrival date.
# * **arrival_date_month** : Month of arrival date.
# * **arrival_date_week_number** : Week number for arrival date.
# * **arrival_date_day_of_month**: Which day of the months guest is arriving.
# * **stays_in_weekend_nights**: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
# * **stays_in_week_nights**: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
# * **adults** : Number of adults.
# * **children** : Number of children.
# * **babies** : Number of babies.
# * **meal**: kind of meal opted for.
# * **country** : Country code.
# * **market_segment**: Through which channel hotels were booked.
# * **distribution_channel** : How the customer accessed the stay- Corporate Booking/Direct/TA.TO
# * **is_repeated_guest** : The values indicating if the booking name was from a repeated guest (1) or not (0).
# * **previous_cancellations** : Was there a cancellation before.
# * **previous_bookings_not_canceled** : Count of previous bookings not cancelled.
# * **reserved_room_type** : Code of room type reserved.
# * **assigned_room_type** : Code for the type of room assigned to the booking.
# * **booking_changes** : Count of changes made to booking.
# * **deposit_type** : Deposit type.
# * **agent** : If the booking happens through agents or not.
# * **company** : If the booking happens through companies, the company ID that made the booking or responsible for paying the booking.
# * **days_in_waiting_list** : Number of days the booking was on the waiting list before the confirmation to the customer.
# * **customer_type** : Booking type like Transient – Transient-Party – Contract – Group.
# * **adr** : Average Daily Rates that described via way of means of dividing the sum of all accommodations transactions using entire numbers of staying nights.
# * **required_car_parking_spaces** : How many parking areas are necessary for the customers.
# * **total_of_special_requests** : Total unique requests from consumers.
# * **reservation_status**: The last status of reservation, assuming one of three categories: Canceled – booking was cancelled by the customer; Check-Out;No-Show.
# * **reservation_status_date**: The last status date.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# fuction to get count of unique values of each column
def col_unique_val_cnt(df):
    try:
        # get columns name in the list
        for col in list(df.columns):
          # nunique() - count the unique values.
          unique_cnt = df[col].nunique()
          print('Column {} has {} unique values'.format(col,unique_cnt))
    except Exception as e:
        print("An error occurred:", {e})
        return df
# get unique values of each column
col_unique_val_cnt(hotel_df)

#print(hotel_booking_df.apply(lambda col: col.unique()))
# Out:
# Column hotel has 2 unique values
# Column is_canceled has 2 unique values
# Column lead_time has 479 unique values
# Column arrival_date_year has 3 unique values
# Column arrival_date_month has 12 unique values
# Column arrival_date_week_number has 53 unique values
# Column arrival_date_day_of_month has 31 unique values
# Column stays_in_weekend_nights has 17 unique values
# Column stays_in_week_nights has 35 unique values
# Column adults has 14 unique values
# Column children has 5 unique values
# Column babies has 5 unique values
# Column meal has 5 unique values
# Column country has 177 unique values
# Column market_segment has 8 unique values
# Column distribution_channel has 5 unique values
# Column is_repeated_guest has 2 unique values
# Column previous_cancellations has 15 unique values
# Column previous_bookings_not_canceled has 73 unique values
# Column reserved_room_type has 10 unique values
# Column assigned_room_type has 12 unique values
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# make a copy of dataframe to work on df
df_copy = hotel_df.copy()

# %%
df_copy
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# Deleting Duplicates values from dataset
df_copy.drop_duplicates(inplace=True)

# Getting count of rows and columns after removed duplicates
print(f'the number of rows: {df_copy.shape[0]} and columns: {df_copy.shape[1]} after removed duplicates')
# Out:
# the number of rows: 87396 and columns: 32 after removed duplicates

# %%
# Calculate the percentage of null values of each column

# function to get percentage of null values
def cal_null_val_percentage(df):
    try:
        # Calculate the percentage of null values
        percent = df.isna().sum()/df.shape[0]*100     # df.isna() or df.isnull()

        # sorting null values in descending order and reset the index and rename the column
        perc_srt = percent.sort_values(ascending=False).reset_index().rename(columns={'index':'Columns',0:'Null %'})

        return perc_srt
    except Exception as e:
        print("An error occurred:", {e})
cal_null_val_percentage(df_copy)
# Out:
#                            Columns     Null %
# 0                          company  93.982562
# 1                            agent  13.951439
# 2                          country   0.517186
# 3                         children   0.004577
# 4               reserved_room_type   0.000000
# 5               assigned_room_type   0.000000
# 6                  booking_changes   0.000000
# 7                     deposit_type   0.000000
# 8                            hotel   0.000000
# 9           previous_cancellations   0.000000
# 10            days_in_waiting_list   0.000000
# 11                   customer_type   0.000000
# 12                             adr   0.000000
# 13     required_car_parking_spaces   0.000000
# 14       total_of_special_requests   0.000000
# 15              reservation_status   0.000000
# 16  previous_bookings_not_canceled   0.000000
# 17               is_repeated_guest   0.000000
# 18                     is_canceled   0.000000
# ...

# %%
# In above result we can see that column company has approx. 94% of missing value
# which is very high so droping the column company
df_copy.drop(columns=['company'],inplace=True)

# %%
# Now check for the Other columns they have less % of null values so replace them with 0

df_copy.fillna({'agent':0,'country':'Others','children':0},inplace=True)

# %%
# checking again for any null values
missing_val_cnt(df_copy)
# Out:
#                             Column  Null Values
# 0                            hotel            0
# 1                      is_canceled            0
# 2                        lead_time            0
# 3                arrival_date_year            0
# 4               arrival_date_month            0
# 5         arrival_date_week_number            0
# 6        arrival_date_day_of_month            0
# 7          stays_in_weekend_nights            0
# 8             stays_in_week_nights            0
# 9                           adults            0
# 10                        children            0
# 11                          babies            0
# 12                            meal            0
# 13                         country            0
# 14                  market_segment            0
# 15            distribution_channel            0
# 16               is_repeated_guest            0
# 17          previous_cancellations            0
# 18  previous_bookings_not_canceled            0
# ...

# %%
df_copy.shape
# Out:
# (87396, 31)

# %%
# Same time adults, childrens, babies cannot be zero so we can drop all the observations having zero at the same time.
df_copy= df_copy[~(df_copy['adults']==0) & (df_copy['children']==0) & (df_copy['babies']==0)]


 #df_copy.drop(df_copy[df_copy['adults']+df_copy['children']+df_copy['babies']==0].index,inplace=True)

# %%
df_copy.shape
# Out:
# (78127, 31)

# %% [markdown]
# #**Check For  DataType**

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78127 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           78127 non-null  object
#  1   is_canceled                     78127 non-null  int64
#  2   lead_time                       78127 non-null  int64
#  3   arrival_date_year               78127 non-null  int64
#  4   arrival_date_month              78127 non-null  object
#  5   arrival_date_week_number        78127 non-null  int64
#  6   arrival_date_day_of_month       78127 non-null  int64
#  7   stays_in_weekend_nights         78127 non-null  int64
#  8   stays_in_week_nights            78127 non-null  int64
#  9   adults                          78127 non-null  int64
#  10  children                        78127 non-null  float64
#  11  babies                          78127 non-null  int64
# ...

# %%
# In above result children and agent column is integer type so it can not be float so we have to convert float datatype into integer datatype
df_copy[['children','agent']] = df_copy[['children','agent']].astype('int64')

# %% [markdown]
# # Additional Column As Per Requirement

# %%
# total stay in the nights
df_copy.loc[:, 'stay in nights'] = df_copy['stays_in_week_nights'] + df_copy['stays_in_weekend_nights']
df_copy['stay in nights']
# Out:
# <ipython-input-27-2e40dca4ef9c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.loc[:, 'stay in nights'] = df_copy['stays_in_week_nights'] + df_copy['stays_in_weekend_nights']
# 0         0
# 1         0
# 2         1
# 3         1
# 4         2
#          ..
# 119385    7
# 119386    7
# 119387    7
# 119388    7
# 119389    9
# Name: stay in nights, Length: 78127, dtype: int64

# %%
# We have created a col for revenue using total stay * adr
df_copy.loc[:,'revenue'] = df_copy['stay in nights'] * df_copy['adr']
df_copy['revenue']
# Out:
# 0            0.00
# 1            0.00
# 2           75.00
# 3           75.00
# 4          196.00
#            ...
# 119385     672.98
# 119386    1578.01
# 119387    1103.97
# 119388     730.80
# 119389    1360.80
# Name: revenue, Length: 78127, dtype: float64

# %%
# for information, we will add a column with total guest coming for each booking
df_copy.loc[:, 'total guests'] = df_copy['adults'] + df_copy['children'] + df_copy['babies']

# Calculate the total number of guests
total_guests = df_copy['total guests'].sum()
total_guests
# Out:
# 146067

# %%
# To provide more precise information from the 'is_canceled' column, replace the values 0 and 1 with 'Not canceled' and 'Canceled' respectively.
df_copy.loc[:, 'is_canceled'] = df_copy['is_canceled'].replace({0: 'Not canceled', 1: 'Canceled'})
df_copy['is_canceled']
# Out:
# 0         Not canceled
# 1         Not canceled
# 2         Not canceled
# 3         Not canceled
# 4         Not canceled
#               ...
# 119385    Not canceled
# 119386    Not canceled
# 119387    Not canceled
# 119388    Not canceled
# 119389    Not canceled
# Name: is_canceled, Length: 78127, dtype: object

# %%
# To provide more precise information from the 'is_repeated_guest' column, replace the values 0 and 1 with 'Not repeated' and 'Repeated' respectively.
df_copy.loc[:, 'is_repeated_guest'] = df_copy['is_repeated_guest'].replace({0: 'Not repeated', 1: 'Repeated'})
df_copy['is_repeated_guest']
# Out:
# 0         Not repeated
# 1         Not repeated
# 2         Not repeated
# 3         Not repeated
# 4         Not repeated
#               ...
# 119385    Not repeated
# 119386    Not repeated
# 119387    Not repeated
# 119388    Not repeated
# 119389    Not repeated
# Name: is_repeated_guest, Length: 78127, dtype: object

# %%
# #Now, we will check overall revenue hotel wise
hotel_wise_total_revenue = df_copy.groupby('hotel')['revenue'].sum()
hotel_wise_total_revenue
#df_copy.loc[:,'revenue'] = pd.to_numeric(df_copy['revenue'], errors='coerce')
# Out:
# hotel
# City Hotel      16171353.83
# Resort Hotel    12609013.61
# Name: revenue, dtype: float64

# %%
df_copy[['hotel','revenue']]
# Out:
#                hotel  revenue
# 0       Resort Hotel     0.00
# 1       Resort Hotel     0.00
# 2       Resort Hotel    75.00
# 3       Resort Hotel    75.00
# 4       Resort Hotel   196.00
# ...              ...      ...
# 119385    City Hotel   672.98
# 119386    City Hotel  1578.01
# 119387    City Hotel  1103.97
# 119388    City Hotel   730.80
# 119389    City Hotel  1360.80
#
# [78127 rows x 2 columns]

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# We have done few manipulations in the Data.
#
# ###i) Addition of columns
#
# We have seen that there are few columns required in Data to analysis purpose which can be evaluated from the given columns.
#
# #####Total Guests:
#
# **Purpose:** To evaluate the total guest volume and facilitate revenue calculations.
#
# *Calculation: Total Guests = Adults + Children + Babies*
#
# **Utility:** Helps in understanding guest demographics, planning resources, and analyzing guest patterns.
#
# #####Revenue:
#
# **Purpose:** To assess the financial performance and profitability of each hotel.
#
# *Calculation: Revenue = ADR (Average Daily Rate) * Total Guests*
#
# **Utility:** Aids in financial analysis, growth trend evaluation, and strategic planning for maximizing profits.
#
# ### ii) Delete of Column
#
# **Company:** Given that this column contains a high proportion of null values, we have decided to remove it from our dataset, as its presence does not significantly contribute to our analysis.
#
# ### iii) Replace of Values in columns
#
# **Booking Status and Guest Repeat:** These columns initially contain binary values (0 and 1), representing different statuses.
#
# To enhance clarity for our analysis and visualization:
#
# **a.** For the is_canceled and is_not_canceled columns, we replace the values 0 and 1 with 'Not Canceled' and 'Canceled', respectively.
#
# **b.** Similarly, in the is_repeated_guest column, we replace the values 0 and 1 with 'Not Repeated' and 'Repeated', respectively.
#
# ###iv) Changes in data type of values in columns
#
# **Agent & Children:** We observed that these columns contain float values, which do not accurately represent the data. Since these columns should indicate the count of guests and the ID of agents, we have converted their data types from 'float' to 'integer' for better accuracy and representation.
#
# ###v) Removed is_null values & duplicate entries
#
# **a)** Prior to visualizing any data from the dataset, it's essential to perform data wrangling. We began by checking for null values across all columns. When a column was found to have a significant number of null values, we removed it using the dropna() method. Consequently, we dropped the company column. For columns with minimal null values, we filled in these gaps with appropriate values using the fillna() method, tailored to meet the specific requirements of the analysis.
#
# **b)** Similarly, we checked for any duplicate entries within the dataset and identified several rows with duplicate data. To ensure the integrity of our analysis, we removed these duplicate rows using the .drop_duplicates() method.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ####Chart - 1
# ####**Which category of hotels sees the highest booking rates?**

# %%
# Chart - 1 visualization code

# sum for total hotel booking
total_hotel_booking = df_copy['hotel'].value_counts().sum()

# count for each type hotel booking
hotel_booking_count = df_copy['hotel'].value_counts()

# written as tuple
perc_city_hotel_booking, perc_resort_hotel_booking= (hotel_booking_count['City Hotel']/total_hotel_booking*100,hotel_booking_count['Resort Hotel']/total_hotel_booking*100)


# Data for the pie chart
labels = ['City Hotel', 'Resort Hotel']
sizes = [perc_city_hotel_booking, perc_resort_hotel_booking]  # Using the calculated percentages
colors = ['#ff9999','#66b3ff']
explode = (0.1, 0)  # Explode the 1st slice (City Hotel)

# Create the pie chart
plt.figure(figsize=(14, 9))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.2f%%', startangle=90)
plt.title('Booking Percentage by Hotel Type')
plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.

# Show the pie chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pie Chart show the proportion of bookings for each hotel in comparison to the total bookings.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **We found that the booking number is higher in City Hotel, accounting for 66.45%, compared to Resort Hotel, which has 33.55%. Hence, we can conclude that City Hotel experiences higher consumption.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, for both hotels, this data is making a positive business impact:**
#
# ***City Hotel:***
#
# **Strategy:**  Provided more services to attract more guests.
#
# **Impact**: Increased revenue through enhanced guest satisfaction and service offerings.
#
# ***Resort Hotel:***
#
# **Strategy**: Find solutions to attract guests by analyzing what City Hotel did successfully.
#
# **Impact**: Implement strategies to draw more guests and boost profitability.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# #### Chart - 2
# #### **Which countries are the guests predominantly from, and from which one do most of them come?**

# %%
guest_country_total = df_copy[df_copy['is_canceled'] == 0]['country'].value_counts().reset_index() # 0 means not cancelled
guest_country_total.columns = ['Country', 'No of guests']
guest_country=guest_country_total.sort_values(by='No of guests',ascending=False).head(10) # Taken Top 10 country in descending order

# Find the maximum value and its index
max_value = guest_country['No of guests'].max()
max_index = guest_country['No of guests'].idxmax() # max_value stores the highest number of guests, and max_index stores the index of this value.

# create bar plot
plt.figure(figsize=(8, 6))
bars =plt.bar(guest_country['Country'], guest_country['No of guests'], color='blue')

# Change the color of the bar with the maximum value
bars[max_index].set_color('green')

plt.xlabel('Country')
plt.ylabel('Number of Guests')
plt.title('Number of Guests by Country')
#plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Bar charts excel at showing comparisons between different categories. In this case, it's the number of guests from different countries. The length of the bars makes it easy to compare the values at a glance.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ***Top Country by Number of Guests:***
#
# **Portugal:** The chart shows that the Portugal has the highest number of guests, with more than 21071 guests. This indicates that the Portugal is the primary source of guests for the hotel.
#
# ***Significant Guest Contributions:***
#
# **GBR(UK) and France:** The UK, with 9676 guests, and France, with 8481 guests, are also significant contributors. These countries represent substantial portions of the guest population.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **The countries and the highlighted maximum value would immediately direct the audience's attention to the most critical data point, facilitating effective decision-making.**

# %% [markdown]
# #### Chart - 3
# #### **Analyze the monthly arrival patterns of guests to identify the busiest, moderately busy, and least occupied months.**

# %%
# Chart - 3 visualization code

# get the Arrival Month and No
arrival_monthly_guest_count = df_copy['arrival_date_month'].value_counts().reset_index()
arrival_monthly_guest_count.columns = ['Arrival Month', 'No of guests']

# month order
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Convert 'Arrival Month' to Categorical type with custom month order
arrival_monthly_guest_count['Arrival Month'] = pd.Categorical(arrival_monthly_guest_count['Arrival Month'], categories=month_order, ordered=True)

# Sort by the defined month order
arrival_monthly_guest_count = arrival_monthly_guest_count.sort_values('Arrival Month')

# Find the max guest month
max_guest_index = arrival_monthly_guest_count['No of guests'].idxmax() # 0
max_guest_month = arrival_monthly_guest_count.loc[max_guest_index, 'Arrival Month'] # August


plt.figure(figsize=(10, 6))
plt.plot(arrival_monthly_guest_count['Arrival Month'], arrival_monthly_guest_count['No of guests'], marker='o', linestyle='-', color='b')

# Highlight the busiest month in red
plt.plot(arrival_monthly_guest_count['Arrival Month'][max_guest_index], arrival_monthly_guest_count['No of guests'][max_guest_index], 'ro')  # 'ro' - red color marker

# Labels and title
plt.xlabel('Arrival Month')
plt.ylabel('Number of Guests')
plt.title('Monthly Arrival Pattern of Guests')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I chose the line chart for visualizing the monthly arrival pattern of guests for **
#
# **1)Time-Series Analysis which help in easily identifying trends, such as peak and low seasons, by showing the rise and fall of guest numbers over the months.**
#
# **2) The continuous line provides a clear and straightforward view of how guest arrivals change from month to month.**
#
# **3)Markers on the line chart help in pinpointing exact values for each month.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Busiest Months:** August have the highest guest counts, indicating peak periods.
#
# **Moderate Months:** May, October, and September have average guest counts, representing steady periods.
#
# **Least Occupancy Months:** January and december have the lowest guest counts, indicating off-peak periods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **The line chart with highlighted maximum guest month provides a clear and immediate understanding of the guest arrival patterns, aiding in strategic planning for staffing, promotions, and resource allocation.**
#
# **These off-peak months could lead to reduced revenue and underutilized resources.**

# %% [markdown]
# #### Chart - 4
# #### **Track the monthly trends in customer cancellations to identify periods of high, moderate, and low cancellation rates.**

# %%
# Chart - 4 visualization code

df_copy[['arrival_date_month','is_canceled']].value_counts().unstack() # unstack(): Converts the multi-level index into columns
# Out:
# is_canceled         Canceled  Not canceled
# arrival_date_month
# April                   2094          5014
# August                  2929          6247
# December                1181          3361
# February                1249          4243
# January                  942          3409
# July                    2662          5709
# June                    2034          4969
# March                   1655          5312
# May                     2199          5538
# November                 986          3756
# October                 1479          4932
# September               1481          4746

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.figure(figsize=(12, 6))
ax=sns.countplot(x='arrival_date_month', hue='is_canceled', data=df_copy, order=month_order, palette='viridis')
plt.xlabel('Arrival Month')
plt.ylabel('Number of Cancellations')
plt.title('Month-wise Customer Cancellations')
plt.legend(title='Cancellation Status', labels=['Not Canceled', 'Canceled'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **1) Count plots directly display the counts of each category, making it easy to see how many cancellations occurred in each month.**
#
# **2) It’s straightforward to compare the number of cancellations across different months.**
#
# **3) Using hues (e.g., 'is_canceled') helps to visually distinguish between canceled and non-canceled bookings within the same plot.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **If you notice that cancellations peak during November, December and January. you might investigate the reasons behind this trend. Perhaps there are seasonal factors, marketing campaigns that didn't resonate well, or service issues during those periods.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **By using the count plot, you can effectively communicate these insights and make informed decisions to address potential issues and improve customer satisfaction.**

# %% [markdown]
# #### Chart - 5
# #### **What is the average duration of stay for hotel guests?**

# %%
# Checking for how long people stay in Resort hotels
resort_hotel = df_copy[df_copy['hotel'] == 'Resort Hotel']
resort_hotel['stay in nights'].value_counts().reset_index()
# Out:
#     stay in nights  count
# 0                1   6463
# 1                7   4903
# 2                2   4421
# 3                3   3776
# 4                4   3457
# 5                5   2135
# 6                6   1321
# 7               10    786
# 8               14    720
# 9                8    592
# 10               9    497
# 11               0    336
# 12              11    266
# 13              12    124
# 14              13     82
# 15              21     43
# 16              28     31
# 17              15     31
# 18              18     16
# 19              16     16
# 20              17     12
# 21              25     12
# 22              19      9
# 23              22      6
# 24              35      5
# 25              30      4
# 26              42      4
# 27              26      3
# 28              29      3
# 29              23      3
# 30              56      2
# 31              45      1
# 32              60      1
# 33              69      1
# ...

# %%
plt.figure(figsize=(12, 6))
ax = sns.countplot(x='stay in nights',data=resort_hotel)
plt.xlabel('Number of Nights in Week')
plt.ylabel('Count')
plt.title('Distribution of Nights in Week')
plt.show()

# %%
# Checking for how long people stay in City hotels
city_hotel = df_copy[df_copy['hotel'] == 'City Hotel']
city_hotel['stay in nights'].value_counts().reset_index()
# Out:
#     stay in nights  count
# 0                3  12237
# 1                2   9821
# 2                1   9348
# 3                4   8669
# 4                5   3697
# 5                7   1640
# 6                6   1424
# 7                8    314
# 8                0    217
# 9                9    171
# 10              10    152
# 11              14     75
# 12              11     58
# 13              12     49
# 14              15     36
# 15              13     34
# 16              16     15
# 17              20     12
# 18              19     10
# 19              29      8
# 20              21      8
# 21              30      8
# 22              17      7
# 23              22      6
# 24              24      6
# 25              18      4
# 26              27      3
# 27              23      2
# 28              26      2
# 29              25      2
# 30              28      2
# 31              48      1
# 32              33      1
# 33              34      1

# %%
plt.figure(figsize=(12, 6))
ax = sns.countplot(x='stay in nights',data=city_hotel)
plt.xlabel('Number of Nights in Week')
plt.ylabel('Count')
plt.title('Distribution of Nights in Week')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I chose the count plot for visualizing the length of stays at City Hotels and Resort Hotels because it effectively represents categorical data and provides clear insights into the distribution of stay durations.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Understanding the length of stay for each hotel type can help with resource allocation, promotional strategies, and enhancing guest experiences.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **if Resort Hotels typically have longer stays, you might focus on amenities and services that cater to extended stays.**

# %% [markdown]
# #### Chart - 6
# #### **What is the primary distribution channel for hotel bookings ?**

# %%
# calculating the Channel %

channel_counts = df_copy['distribution_channel'].value_counts()
channel_percentages = channel_counts / channel_counts.sum()*100
channel_percentages
# Out:
# distribution_channel
# TA/TO        79.087895
# Direct       14.267795
# Corporate     6.407516
# GDS           0.231674
# Undefined     0.005120
# Name: count, dtype: float64

# %%
# Plotting the data using a pie chart
plt.figure(figsize=(8, 8))

# Removed Undefined distribution_channel
plt.pie(channel_percentages.iloc[:3], labels=channel_percentages.iloc[:3].index,startangle=60,  autopct='%1.1f%%', colors=['#5DADE2', '#48C9B0', '#F4D03F'])
plt.title('Distribution of Bookings by Channel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **The pie chart will show the proportion of bookings made through each distribution channel, making it easy to see which channel is most popular and how the others compare.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Understanding the distribution of bookings across different channels helps you make informed decisions about where to focus marketing and distribution efforts.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **if the Direct channel is the most common, you might prioritize resources and strategies to further enhance this channel.**

# %% [markdown]
# #### Chart - 7
# #### **Which agent generates the highest number of bookings ?**

# %%
# getting count of agent booking and taking 20 agent data
agent_booking_count = df_copy.loc[df_copy['agent']!=0,'agent'].value_counts().reset_index()[:20]
agent_booking_count
# Out:
#     agent  count
# 0       9  25416
# 1     240  11085
# 2       7   2908
# 3      14   2787
# 4     250   2215
# 5      28   1410
# 6     241   1373
# 7       8   1233
# 8       1   1215
# 9       6   1051
# 10     40    962
# 11    314    759
# 12    242    592
# 13     85    514
# 14     83    507
# 15    243    463
# 16     27    391
# 17    171    377
# 18      3    350
# 19     22    299

# %%
plt.figure(figsize=(12, 6))
plt.bar(agent_booking_count['agent'], agent_booking_count['count'], color='skyblue', width=5, edgecolor='black')
plt.xlabel('Agent ID')
plt.ylabel('Number of Bookings')
plt.title('Number of Bookings by Agent')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Bar charts provide an intuitive way to compare the number of bookings across different agents, with each bar representing the booking count of an agent.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **This bar chart will visually represent the number of bookings made by each agent, making it easy to see which agent has the most bookings.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **we can analyze the booking data and identify the top-performing agent. This information can provide valuable insights into business operations and help strategize for better performance.**

# %% [markdown]
# #### Chart - 8
# #### **Which hotel boasts the highest Average Daily Rate (ADR), indicating potentially greater revenue generation ?**

# %%
hotels_adr = df_copy[['hotel','adr']].groupby('hotel').mean().reset_index()
hotels_adr
# Out:
#           hotel         adr
# 0    City Hotel  107.054630
# 1  Resort Hotel   91.020722

# %%
# change the color for City Hotel and Resort hotel
colors = ['blue' if hotel == 'City Hotel' else 'green' for hotel in hotels_adr['hotel']]

plt.figure(figsize=(12, 6))
sns.barplot(x='hotel', y='adr', data=df_copy, palette=colors,hue='hotel')
plt.xlabel('Hotel')
plt.ylabel('Average Daily Rate (ADR)')
plt.title('Average Daily Rate by Hotel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We picked a bar chart for this analysis because it effectively represents categorical data and provides clear comparisons between different categories, in this case, the Average Daily Rate (ADR) for City Hotels and Resort Hotels.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **With an average occupancy rate of 91% and higher revenue, the Resort Hotel outperforms the City Hotel in terms of both occupancy and revenue generation
# Analyzing occupancy rates alongside ADR provides a comprehensive view of hotel performance, helping to make informed decisions for maximizing revenue and guest satisfaction.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Revenue Optimization: A higher occupancy rate indicates efficient use of available rooms, leading to increased revenue.**
#
# **Resource Allocation: Focus on maintaining and improving occupancy rates through effective marketing and customer service strategies.**

# %% [markdown]
# #### Chart - 9
# #### **What is the pattern of nightly rates throughout the year ?**

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Convert 'arrival_date_month' to a categorical type with the specified order
df_copy['arrival_date_month'] = pd.Categorical(df_copy['arrival_date_month'], categories=month_order, ordered=True)

# Calculating the mean of adr
night_rate = df_copy.groupby('arrival_date_month',observed=True)['adr'].mean().reset_index() # To Avoid Warning Add observed=True in groupby
night_rate
# Out:
# <ipython-input-50-5088f4b652ec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['arrival_date_month'] = pd.Categorical(df_copy['arrival_date_month'], categories=month_order, ordered=True)
#    arrival_date_month         adr
# 0             January   67.665259
# 1            February   71.252861
# 2               March   79.098016
# 3               April   98.534879
# 4                 May  108.103324
# 5                June  114.970937
# 6                July  127.795621
# 7              August  142.036323
# 8           September  108.606896
# 9             October   87.545224
# 10           November   71.830732
# 11           December   77.376178

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='arrival_date_month',y='adr',data=df_copy,hue='hotel',hue_order=['City Hotel','Resort Hotel'],palette= {'City Hotel':'Green','Resort Hotel':"Blue"})
plt.xlabel('Arrival Month')
plt.ylabel('Average Daily Rate (ADR) in $')
plt.grid(True)
plt.title('Nightly Rates Throughout the Year')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To understand how the price per night varies over the year, we can use a line chart. This type of chart is particularly effective for visualizing trends over time.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **This plot will show the variation in ADR over the year for each hotel type, highlighting any seasonal trends and differences between 'City Hotel' and 'Resort Hotel'.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Understanding these trends helps in making data-driven decisions to optimize revenue, enhance guest satisfaction, and plan effective marketing strategies.**

# %% [markdown]
# #### Chart - 10
# #### **Contrast the waiting list duration and lead time for both canceled and availed bookings.**

# %%
# Removed 0 duration from waiting_booking duration
waiting_booking = df_copy[df_copy['days_in_waiting_list']!=0]

# side-by-side KDE plots to compare the distributions of waiting list days and lead time for canceled and availed stays
fig,ax=plt.subplots(1,2,figsize=(15,5))

sns.kdeplot(data=df_copy,x='lead_time',hue='is_canceled',ax=ax[0],fill=True)
sns.kdeplot(data=waiting_booking,x='days_in_waiting_list',hue='is_canceled',ax=ax[1],fill=True)

ax[0].set_title('Lead Time Distribution')
ax[1].set_title('Waiting List Duration Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **KDE plots provide a smooth approximation of the density distribution, making it easier to visualize and compare the patterns for canceled and availed stays.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **By plotting the KDEs for both canceled and availed stays on the same axes, you can directly compare the distributions and identify any differences or similarities.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **This optimized code helps visualize the density distributions of waiting list days and lead time for canceled versus availed stays, providing valuable insights for improving booking strategies and operational efficiency.**

# %% [markdown]
# #### Chart - 11
# #### **How do repeat guests affect the rate of cancellations?**

# %%
# cancellation and Repeated guest relation
df_copy[['is_repeated_guest','is_canceled']].value_counts().unstack()
# Out:
# is_canceled        Canceled  Not canceled
# is_repeated_guest
# Not repeated          20635         54224
# Repeated                256          3012

# %%
plt.figure(figsize=(12, 6))

ax = sns.countplot(x='is_canceled', hue='is_repeated_guest', data=df_copy, palette={ 0: 'green', 1:'red'})

plt.xlabel('Repeated Guest')
plt.ylabel('Count')
plt.title('Cancellation and Repeated Guest Relation')
plt.legend(title='Cancellation Status', labels=['Not Canceled', 'Canceled'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **The countplot provides a clear visual comparison of cancellation counts between new and repeated guests.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **New Guests:** Higher cancellation rates can indicate uncertainty or lack of commitment.
#
# **Returning Guests:** Lower cancellation rates reflect loyalty, trust, and satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **The impact of repeated guests on cancellation rates can help hotels design better loyalty programs, improve guest experiences, and ultimately reduce cancellation rates.**

# %% [markdown]
# #### Chart - 12
# #### **What are the cancellation patterns in various market segments?**

# %%
plt.figure(figsize=(12, 6))

ax = sns.countplot(x='market_segment', hue='is_canceled', data=df_copy, palette={0: 'green', 1: 'red'})

plt.xlabel('Market Segment')
plt.ylabel('Count')
plt.title('Cancellation Patterns by Market Segment')
plt.legend(title='Cancellation Status', labels=['Not Canceled', 'Canceled'])
plt.xticks(rotation=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **The countplot provides a clear visual comparison of cancellation counts within each market segment.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The countplot may show that a significant portion of direct bookings are canceled.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Use dynamic pricing and flexible cancellation policies to manage the segments with higher cancellation rates.**

# %% [markdown]
# #### Chart - 13
# ####**Which distribution channel sees the highest early bookings for hotels?**

# %%
# shown the median of lead time group by distribution_channel in descending order [Taken meadian instead of mean(average) because of outliers]
early_booking_dc = df_copy.groupby("distribution_channel")['lead_time'].median().sort_values(ascending=False).reset_index()
early_booking_dc
# Out:
#   distribution_channel  lead_time
# 0                TA/TO       61.0
# 1               Direct       13.0
# 2                  GDS       10.0
# 3            Corporate        6.0
# 4            Undefined        1.5

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='distribution_channel', y='lead_time', hue='distribution_channel' , data=early_booking_dc, palette='viridis')
plt.xlabel('Distribution Channel')
plt.ylabel('Median Lead Time')
plt.title('Distribution Channel with Highest Early Bookings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A barplot provides a straightforward visual comparison of different categories, making it easy to see which distribution channel has the highest frequency of early bookings.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **1) The bar plot provides a clear visual comparison of the number of early bookings across different distribution channels.**
#
# **2) Identify which distribution channels are most effective in securing early bookings.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **1) Focus marketing efforts on the channels that generate the highest early bookings.**
#
# **2) Use insights to create strategies that encourage early bookings, such as early bird discounts or special promotions.**

# %% [markdown]
# #### Chart - 14 - **Correlation Heatmap**

# %%
# Correlation Heatmap visualization code
corr_df = df_copy[['lead_time', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'days_in_waiting_list','adr',
          'required_car_parking_spaces','total_of_special_requests']]

# calculates the correlation matrix. (1 = perfect positive correlation, -1 = perfect negative correlation, 0 = no correlation)
corr_matrix=corr_df.corr()

plt.figure(figsize=(10,5))

sns.heatmap(corr_matrix, vmin=-1,annot=True,cmap='coolwarm') # vmin=1 - minimum value of the heatmap color scale to -1
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **By using a heatmap to visualize the correlation matrix, you gain a comprehensive overview of how different features relate to each other, enabling more informed decisions in your analysis and strategy development.**
#
# **Color Scale:**
#
# ***Red Colors:*** Represent positive correlations. The more intense the red, the stronger the positive correlation.
#
# ***Blue Colors:*** Represent negative correlations. The more intense the blue, the stronger the negative correlation.
#
# ***White/Neutral Colors:*** Represent correlations close to zero, indicating no strong relationship.
#
# **Annotations:** Each cell is annotated with the correlation value, making it easy to see the exact correlation between pairs of features.
#
# **Diagonal:** The diagonal represents the correlation of each feature with itself, which is always 1 (perfect correlation).
#
# **vmin=-1:** Sets the minimum value of the heatmap color scale to -1.
#
# **annot=True:** Annotates each cell with the numeric value of the correlation.
#
# **cmap='coolwarm':** where cool colors (blue) represent negative correlations and warm colors (red) represent positive correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Lead Time vs. Previous Cancellations:** If the correlation is negative, it might indicate that guests with longer lead times have fewer previous cancellations.
#
# **Days in Waiting List vs. Required Car Parking Spaces:** A low correlation (close to zero) suggests that these two features are not related.
#
# **ADR (Average Daily Rate) vs. Total of Special Requests:** A positive correlation suggests that higher ADRs might be associated with more special requests.

# %% [markdown]
# #### Chart - 15 - **Pair Plot**

# %%
df = df_copy[['is_canceled','days_in_waiting_list','lead_time','distribution_channel']]
sns.pairplot(df, hue='is_canceled', palette={0: 'green', 1: 'red'})

# adds a title to the plot
plt.suptitle('Pairplot of Hotel Booking Features', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pairplots, generated using Seaborn's pairplot() function, show pairwise relationships and distributions of multiple variables in a dataset.**
#
# **Lead Time:** Observe the central tendency (mean, median) and spread (variance). Identify any skewness that might suggest most bookings are made very early or very close to the travel date.
#
# **Days in Waiting List:** Look for common waiting periods and any spikes that indicate frequent waiting durations. This helps understand operational efficiency.
#
# **Distribution Channel:** If shown as frequency counts, identify the most used channels. This informs marketing and partnership strategies.
#
# **Cancellation Status:** Review the overall proportion of canceled vs. non-canceled bookings. This reveals the cancellation pattern in your dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Cancellation Trends:** Identify if long lead times or certain distribution channels are associated with higher cancellation rates.
#
# **Booking Strategies:** Use insights to develop strategies to reduce cancellations, such as focusing on channels with lower cancellation rates or optimizing lead times.
#
# **Operational Efficiency:** Improve operational strategies by understanding the relationship between waiting list duration and cancellation likelihood.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
#
# ***To help the client achieve their business objectives, I would suggest the following actionable strategies, particularly focusing on reducing cancellation rates and improving booking stability based on the insights from the data analysis and visualizations like pairplots and heatmaps:***
#
# ***Enhance Direct Booking Channels:***
#
# 1. Implement loyalty programs that reward repeat guests with discounts, special amenities, or loyalty points that encourage direct bookings and reduce cancellations.
#
# ***Optimize Pricing and Offers:***
#
# 1. Implement dynamic pricing strategies that adjust rates based on demand, booking lead times, and market conditions to maximize revenue and encourage early bookings.
#
# ***Improve Distribution Channel Management:***
#
# 1. Regularly analyze the performance of different distribution channels to understand which ones yield the highest quality bookings.
#
# 2. Work with corporate clients and travel agencies to offer negotiated rates and packages that incentivize longer stays and advance bookings.
#
# ***Enhance Guest Experience:***
#
# 1. Invest in training staff to provide exceptional customer service, creating positive experiences that encourage repeat visits and reduce cancellations.
#
# 2. Introduce flexible booking policies, such as easy cancellation or rescheduling options, to provide peace of mind for guests and reduce the likelihood of cancellations.
#
# ***Leverage Data-Driven Insights:***
#
# 1. Continuously monitor key performance indicators (KPIs) such as cancellation rates, lead times, and channel performance to make informed decisions and adjustments.
#
# ***Engage in Continuous Improvement:***
#
# Stay updated with industry trends and innovations. Adapt to changing market conditions and guest preferences to remain competitive and attractive to potential guests.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. **City Hotel** is preferred among travelers, generating higher revenue and profit compared to other options.
#
# 2. **July and August** see the highest number of bookings, indicating peak travel months.
#
# 3. **The nightly rate** fluctuates with the seasons, with the **highest average daily rates** occurring during peak booking months.
#
# 4. Most bookings come from **Portugal and Great Britain**.
#
# 5. **Guests typically stay for 1-4 days.**
#
# 6. **City Hotel** retains a higher number of guests compared to others.
#
# 7. **Approximately one-fourth** of all bookings are canceled, with **City Hotel** experiencing the majority of these cancellations.
#
# 8. **New guests** are more likely **to cancel bookings than repeat customers**.
#
# 9. Factors like **lead time, waiting list duration, and room assignment** do not significantly affect booking cancellations.
#
# 10. **Corporate bookings** have the highest percentage of repeat guests, while **TA/TO bookings** have the highest cancellation rates and the least number of repeated guests.
#
# 11. **The length of stay decreases** as **the average daily rate (ADR)** increases, likely to manage costs.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
